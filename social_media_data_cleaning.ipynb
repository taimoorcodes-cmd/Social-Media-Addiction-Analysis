# %%
import pandas as pd

# 1. Define the exact path to our file (using 'r' before the string to handle backslashes safely)
file_path = r"C:\Users\Decent\OneDrive\Documents\tiktok ,instragram data.csv"

# 2. Load the CSV file into a Pandas DataFrame
try:
    df = pd.read_csv(file_path)
    print("🚀 Team Success! The dataset has loaded perfectly into Pandas, boss.")
    print(f"Total Rows: {df.shape[0]} | Total Columns: {df.shape[1]}")
except Exception as e:
    print("❌ Oops! Something went wrong while loading the file. Error details:")
    print(e)

# 3. Let's look at the first 5 rows to see what columns we have
df.head()
# Out:
# 🚀 Team Success! The dataset has loaded perfectly into Pandas, boss.
# Total Rows: 10000 | Total Columns: 23
#    user_id      country  age  year  internet_penetration  \
# 0        1  Philippines   59  2050             88.895513
# 1        2  Netherlands   23  2035             57.950292
# 2        3         Laos   26  2060             40.325805
# 3        4     Bulgaria   50  2046             43.838044
# 4        5       Zambia   24  2045             43.749943
#
#    mental_health_support_index  gdp_index  youth_population_ratio  \
# 0                    64.347080   0.312067                0.310389
# 1                    76.257045   0.460320                0.293134
# 2                    55.846514   0.893658                0.183055
# 3                    28.390576   0.661523                0.155038
# 4                    81.413755   0.275186                0.457115
#
#    baseline_addiction_pressure  tiktok_minutes_daily  ...  addiction_pressure  \
# ...

# %%
# Check data information
print(df.info())

# Check first 5 rows
print(df.head())

# Check column names
print(df.columns)

# Check missing values
print(df.isnull().sum())

# Check duplicate rows
print("Duplicate Rows:", df.duplicated().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 23 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   user_id                      10000 non-null  int64
#  1   country                      10000 non-null  object
#  2   age                          10000 non-null  int64
#  3   year                         10000 non-null  int64
#  4   internet_penetration         10000 non-null  float64
#  5   mental_health_support_index  10000 non-null  float64
#  6   gdp_index                    10000 non-null  float64
#  7   youth_population_ratio       10000 non-null  float64
#  8   baseline_addiction_pressure  10000 non-null  float64
#  9   tiktok_minutes_daily         10000 non-null  float64
#  10  instagram_minutes_daily      10000 non-null  float64
#  11  night_usage_ratio            10000 non-null  float64
# ...

# %%
print(df['addiction_level'].value_counts())
# Out:
# addiction_level
# High      8680
# Medium    1198
# Low        121
# Severe       1
# Name: count, dtype: int64

# %%
print(df['country'].nunique())
print(df['country'].value_counts().head(10))
# Out:
# 100
# country
# Netherlands    127
# El Salvador    121
# Turkey         121
# Denmark        118
# Angola         118
# Russia         117
# Uganda         116
# Germany        115
# Sri Lanka      114
# Iraq           114
# Name: count, dtype: int64

# %%
print(df.describe().T)
# Out:
#                                count         mean          std          min  \
# user_id                      10000.0  5000.500000  2886.895680     1.000000
# age                          10000.0    35.744800    13.495551    13.000000
# year                         10000.0  2037.435100    13.220419  2015.000000
# internet_penetration         10000.0    67.947220    17.376643    40.325805
# mental_health_support_index  10000.0    55.188221    20.446164    20.486649
# gdp_index                    10000.0     0.614310     0.232364     0.204049
# youth_population_ratio       10000.0     0.320566     0.101786     0.155038
# baseline_addiction_pressure  10000.0    51.085025    19.130635    20.650259
# tiktok_minutes_daily         10000.0   120.918463    58.319304     0.000000
# instagram_minutes_daily      10000.0   100.110930    49.319921     0.000000
# night_usage_ratio            10000.0     0.504368     0.286704     0.000129
# ...

# %%
print(df['ASI'].value_counts().head(10))
# Out:
# ASI
# 100.000000    7757
# 75.112797        1
# 43.153231        1
# 98.792472        1
# 63.903755        1
# 92.496185        1
# 83.959340        1
# 92.293459        1
# 70.575314        1
# 81.865177        1
# Name: count, dtype: int64

# %%
print(df.shape)
# Out:
# (10000, 23)

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = create_engine(
    "mysql+pymysql://root:Taimoor123$@localhost/social_media_analytics"
)

print("Connection Created Successfully!")
# Out:
# Connection Created Successfully!

# %%
df.to_sql(
    name='social_media_data',
    con=engine,
    if_exists='replace',
    index=False
)

print("Data exported successfully!")
# Out:
# Data exported successfully!
